# %%
pip install mediapipe

# %%
pip install pyautogui
# Out:
# Collecting pyautogui
#   Downloading PyAutoGUI-0.9.54.tar.gz (61 kB)
#      ---------------------------------------- 0.0/61.2 kB ? eta -:--:--
#      ------ --------------------------------- 10.2/61.2 kB ? eta -:--:--
#      ------------------- ------------------ 30.7/61.2 kB 262.6 kB/s eta 0:00:01
#      -------------------------------------- 61.2/61.2 kB 326.9 kB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting pymsgbox (from pyautogui)
#   Downloading PyMsgBox-1.0.9.tar.gz (18 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting pytweening>=1.0.4 (from pyautogui)
#   Downloading pytweening-1.0.7.tar.gz (168 kB)
#      ---------------------------------------- 0.0/168.2 kB ? eta -:--:--
#      -------------- ------------------------ 61.4/168.2 kB 1.1 MB/s eta 0:00:01
#      -------------------------------------- 168.2/168.2 kB 2.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting pyscreeze>=0.1.21 (from pyautogui)
#   Downloading PyScreeze-0.1.29.tar.gz (25 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting pygetwindow>=0.0.5 (from pyautogui)
#   Downloading PyGetWindow-0.0.9.tar.gz (9.7 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting mouseinfo (from pyautogui)
#   Downloading MouseInfo-0.1.3.tar.gz (10 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting pyrect (from pygetwindow>=0.0.5->pyautogui)
#   Downloading PyRect-0.2.0.tar.gz (17 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting pyscreenshot (from pyscreeze>=0.1.21->pyautogui)
#   Downloading pyscreenshot-3.1-py3-none-any.whl (28 kB)
# Requirement already satisfied: Pillow>=9.2.0 in c:\users\hp\anaconda3\envs\virtual_for_mrcnn\lib\site-packages (from pyscreeze>=0.1.21->pyautogui) (10.0.0)
# Collecting pyperclip (from mouseinfo->pyautogui)
#   Downloading pyperclip-1.8.2.tar.gz (20 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting EasyProcess (from pyscreenshot->pyscreeze>=0.1.21->pyautogui)
#   Downloading EasyProcess-1.1-py3-none-any.whl (8.7 kB)
# Collecting entrypoint2 (from pyscreenshot->pyscreeze>=0.1.21->pyautogui)
#   Downloading entrypoint2-1.1-py2.py3-none-any.whl (9.9 kB)
# Collecting mss (from pyscreenshot->pyscreeze>=0.1.21->pyautogui)
#   Downloading mss-9.0.1-py3-none-any.whl (22 kB)
# Building wheels for collected packages: pyautogui, pygetwindow, pyscreeze, pytweening, mouseinfo, pymsgbox, pyperclip, pyrect
#   Building wheel for pyautogui (pyproject.toml): started
#   Building wheel for pyautogui (pyproject.toml): finished with status 'done'
#   Created wheel for pyautogui: filename=PyAutoGUI-0.9.54-py3-none-any.whl size=37597 sha256=6fdc623692ab6a2fc88f1300872c6a65de01a7be618e45ba16485b97815f771a
#   Stored in directory: c:\users\hp\appdata\local\pip\cache\wheels\b6\5b\b6\c9ff932c5c4357f394b197f9442bda12a646cce8909cab8657
#   Building wheel for pygetwindow (setup.py): started
#   Building wheel for pygetwindow (setup.py): finished with status 'done'
#   Created wheel for pygetwindow: filename=PyGetWindow-0.0.9-py3-none-any.whl size=11079 sha256=53eeeb04f09836b04b7205077f53511be89b0bf78d07ac3cc12f532677b99845
#   Stored in directory: c:\users\hp\appdata\local\pip\cache\wheels\91\e3\04\184bda98ec7f7d5f0ba1f372bcf7b3ba86325151ae1dd690fe
#   Building wheel for pyscreeze (pyproject.toml): started
#   Building wheel for pyscreeze (pyproject.toml): finished with status 'done'
#   Created wheel for pyscreeze: filename=PyScreeze-0.1.29-py3-none-any.whl size=13484 sha256=332fa959404ab76571f5940e2cd6a0680bc7227d221fbc056e51b564d1c6db28
#   Stored in directory: c:\users\hp\appdata\local\pip\cache\wheels\f3\70\ce\dbcea8bbe0e6f0fdb39be36005709a73916ad3feef872290b0
#   Building wheel for pytweening (setup.py): started
#   Building wheel for pytweening (setup.py): finished with status 'done'
#   Created wheel for pytweening: filename=pytweening-1.0.7-py3-none-any.whl size=6214 sha256=6fa59ea8e7c1e5c0dcdb562661aef9db23553a68baf5a54c39f4c36c71050c17
#   Stored in directory: c:\users\hp\appdata\local\pip\cache\wheels\ca\fd\7a\e38775e324c28f8a8a423f3d79c423be6dbb543bc36d41faa0
#   Building wheel for mouseinfo (setup.py): started
#   Building wheel for mouseinfo (setup.py): finished with status 'done'
#   Created wheel for mouseinfo: filename=MouseInfo-0.1.3-py3-none-any.whl size=10906 sha256=31e0a71fa8ea00085817ecfe387f052bb361e1f6247ac6bd76bd1bdfe1b4b3a1
#   Stored in directory: c:\users\hp\appdata\local\pip\cache\wheels\d1\72\fb\35f403de66285df8ecca7049bcc61bfb57aba0f76d1f08f7eb
#   Building wheel for pymsgbox (pyproject.toml): started
#   Building wheel for pymsgbox (pyproject.toml): finished with status 'done'
#   Created wheel for pymsgbox: filename=PyMsgBox-1.0.9-py3-none-any.whl size=7417 sha256=c075fcef5b1db6a019279a89921cf8dab1de64a32f55a394776c70037e1c021c
#   Stored in directory: c:\users\hp\appdata\local\pip\cache\wheels\91\28\0d\f4eb606d38276836237d6dc2abf094241e6db5682a126e0389
#   Building wheel for pyperclip (setup.py): started
#   Building wheel for pyperclip (setup.py): finished with status 'done'
#   Created wheel for pyperclip: filename=pyperclip-1.8.2-py3-none-any.whl size=11137 sha256=cb125178db5169d48a46a8de2709353a6ad083fb7408ca63e0db4de9dd4e402a
#   Stored in directory: c:\users\hp\appdata\local\pip\cache\wheels\7f\1a\65\84ff8c386bec21fca6d220ea1f5498a0367883a78dd5ba6122
#   Building wheel for pyrect (setup.py): started
#   Building wheel for pyrect (setup.py): finished with status 'done'
#   Created wheel for pyrect: filename=PyRect-0.2.0-py2.py3-none-any.whl size=11205 sha256=074437147fdc93702b51572cd007fa8e90af92bcc237ca0ef46bb35d6ca50ad1
#   Stored in directory: c:\users\hp\appdata\local\pip\cache\wheels\1b\c1\cc\3d6515746ab138a303b6b5d38181399703488f8109b734e768
# Successfully built pyautogui pygetwindow pyscreeze pytweening mouseinfo pymsgbox pyperclip pyrect
# Installing collected packages: pytweening, pyrect, pyperclip, pymsgbox, entrypoint2, EasyProcess, pygetwindow, mss, mouseinfo, pyscreenshot, pyscreeze, pyautogui
# Successfully installed EasyProcess-1.1 entrypoint2-1.1 mouseinfo-0.1.3 mss-9.0.1 pyautogui-0.9.54 pygetwindow-0.0.9 pymsgbox-1.0.9 pyperclip-1.8.2 pyrect-0.2.0 pyscreenshot-3.1 pyscreeze-0.1.29 pytweening-1.0.7
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The script mss.exe is installed in 'C:\Users\HP\anaconda3\envs\Virtual_for_MRCNN\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.

# %%
import cv2
import mediapipe as mp
import pyautogui
cap = cv2.VideoCapture(0)
hand_detector = mp.solutions.hands.Hands()
drawing_utils = mp.solutions.drawing_utils
screen_width, screen_height = pyautogui.size()
index_y = 0
while True:
    _, frame = cap.read()
    frame = cv2.flip(frame, 1)
    frame_height, frame_width, _ = frame.shape
    rgb_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
    output = hand_detector.process(rgb_frame)
    hands = output.multi_hand_landmarks
    if hands:
        for hand in hands:
            drawing_utils.draw_landmarks(frame, hand)
            landmarks = hand.landmark
            for id, landmark in enumerate(landmarks):
                x = int(landmark.x*frame_width)
                y = int(landmark.y*frame_height)
                if id == 8:
                    cv2.circle(img=frame, center=(x,y), radius=10, color=(0, 255, 255))
                    index_x = screen_width/frame_width*x
                    index_y = screen_height/frame_height*y

                if id == 4:
                    cv2.circle(img=frame, center=(x,y), radius=10, color=(0, 255, 255))
                    thumb_x = screen_width/frame_width*x
                    thumb_y = screen_height/frame_height*y
                    print('outside', abs(index_y - thumb_y))
                    if abs(index_y - thumb_y) < 20:
                        pyautogui.click()
                        pyautogui.sleep(1)
                    elif abs(index_y - thumb_y) < 100:
                        pyautogui.moveTo(index_x, index_y)
    cv2.imshow('Virtual Mouse', frame)
    cv2.waitKey(1)
# Out:
# outside 805.5
# outside 164.25
# outside 168.75
# outside 123.75
# outside 105.75
# outside 65.25
# outside 51.75
# outside 18.0
# outside 148.5
# outside 202.5
# outside 198.0
# outside 202.5
# outside 204.75
# outside 204.75
# outside 207.0
# outside 207.0
# outside 209.25
# outside 204.75
# outside 207.0
# outside 207.0
# outside 207.0
# outside 207.0
# outside 202.5
# outside 204.75
# outside 207.0
# outside 207.0
# outside 207.0
# outside 207.0
# outside 207.0
# outside 207.0
# outside 207.0
# outside 211.5
# outside 209.25
# outside 209.25
# outside 204.75
# outside 209.25
# outside 209.25
# outside 204.75
# outside 211.5
# outside 209.25
# outside 200.25
# outside 198.0
# outside 195.75
# outside 193.5
# outside 200.25
# outside 202.5
# outside 198.0
# outside 198.0
# outside 191.25
# outside 193.5
# outside 191.25
# outside 193.5
# outside 189.0
# outside 184.5
# outside 189.0
# outside 184.5
# outside 186.75
# outside 186.75
# outside 184.5
# outside 189.0
# outside 182.25
# outside 186.75
# outside 189.0
# outside 191.25
# outside 191.25
# outside 186.75
# outside 180.0
# outside 168.75
# outside 168.75
# outside 168.75
# outside 200.25
# outside 177.75
# outside 164.25
# outside 135.0
# outside 117.0
# outside 108.0
# outside 121.5
# outside 108.0
# outside 119.25
# outside 121.5
# outside 135.0
# outside 119.25
# outside 144.0
# outside 132.75
# outside 155.25
# outside 164.25
# outside 121.5
# outside 117.0
# outside 112.5
# outside 126.0
# outside 114.75
# outside 108.0
# outside 105.75
# outside 135.0
# outside 101.25
# outside 108.0
# outside 207.0
# outside 13.5
# outside 114.75
# outside 85.5
# outside 130.5
# outside 110.25
# outside 110.25
# outside 110.25
# outside 112.5
# outside 108.0
# outside 112.5
# outside 103.5
# outside 94.5
# outside 92.25
# outside 76.5
# outside 83.25
# outside 90.0
# outside 87.75
# outside 78.75
# outside 85.5
# outside 101.25
# outside 198.0
# outside 175.5
# outside 162.0
# outside 171.0
# outside 76.5
# outside 99.0
# outside 146.25
# outside 114.75
# outside 90.0
# outside 85.5
# outside 4.5
# outside 123.75
# outside 11.25
# outside 65.25
# outside 72.0
# outside 56.25
# outside 27.0
# outside 78.75
# outside 85.5
# outside 56.25
# outside 38.25
# outside 33.75
# outside 56.25
# outside 58.5
# outside 58.5
# outside 49.5
# outside 45.0
# outside 42.75
# outside 58.5
# outside 47.25
# outside 47.25
# outside 126.0
# outside 54.0
# outside 56.25
# outside 85.5
# outside 139.5
# outside 72.0
# outside 65.25
# outside 54.0
# outside 36.0
# outside 58.5
# outside 49.5
# outside 47.25
# outside 36.0
# outside 22.5
# outside 29.25
# outside 31.5
# outside 54.0
# outside 42.75
# outside 42.75
# outside 15.75
# outside 27.0
# outside 9.0
# outside 4.5
# outside 47.25
# outside 31.5
# outside 20.25
# outside 24.75
# outside 67.5
# outside 11.25
# outside 18.0
# outside 24.75
# outside 65.25
# outside 42.75
# outside 42.75
# outside 33.75
# outside 36.0
# outside 56.25
# outside 27.0
# outside 36.0
# outside 54.0
# outside 49.5
# outside 47.25
# outside 92.25
# outside 92.25
# outside 92.25
# outside 135.0
# outside 105.75
# outside 103.5
# outside 105.75
# outside 78.75
# outside 29.25
# outside 42.75
# outside 63.0
# outside 103.5
# outside 148.5
# outside 146.25
# outside 112.5
# outside 123.75
# outside 110.25
# outside 105.75
# outside 94.5
# outside 123.75
# outside 128.25
# outside 130.5
# outside 130.5
# outside 132.75
# outside 135.0
# outside 132.75
# outside 141.75
# outside 144.0
# outside 146.25
# outside 148.5
# outside 126.0
# outside 213.75
# outside 794.25
# outside 101.25
# outside 31.5
# outside 31.5
# outside 2.25
# outside 137.25
# outside 60.75
# outside 254.25
# outside 110.25
# outside 92.25
# outside 267.75
# outside 31.5
# outside 301.5
# outside 40.5
# outside 126.0
# outside 362.25
# outside 243.0
# outside 162.0
# outside 245.25
# outside 256.5
# outside 281.25
# outside 245.25
# outside 297.0
# outside 265.5
# outside 297.0
# outside 303.75
# outside 290.25
# outside 335.25
# outside 297.0
# outside 272.25
# outside 342.0
# outside 409.5
# outside 297.0
# outside 463.5
# outside 209.25
# outside 11.25
# outside 99.0
# outside 60.75
# outside 72.0
# outside 27.0
# outside 36.0
# outside 9.0
# outside 87.75
# outside 9.0
# outside 2.25
# outside 15.75
# outside 49.5
# outside 56.25
# outside 72.0
# outside 60.75
# outside 69.75
# outside 65.25
# outside 72.0
# outside 69.75
# outside 65.25
# outside 60.75
# outside 60.75
# outside 63.0
# outside 56.25
# outside 60.75
# outside 65.25
# outside 67.5
# outside 63.0
# outside 65.25
# outside 60.75
# outside 67.5
# outside 63.0
# outside 69.75
# outside 69.75
# outside 69.75
# outside 60.75
# outside 65.25
# outside 67.5
# outside 67.5
# outside 67.5
# outside 58.5
# outside 29.25
# outside 18.0
# outside 216.0
# outside 69.75
# outside 40.5
# outside 20.25
